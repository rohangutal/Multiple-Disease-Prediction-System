# %% [markdown]
# # Heart Disease Prediction

# %% [markdown]
# ## import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("heart.csv")

# %%
data.head()
# Out:
#    Age  Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0   40    1           ATA        140          289          0     Normal
# 1   49    0           NAP        160          180          0     Normal
# 2   37    1           ATA        130          283          0         ST
# 3   48    0           ASY        138          214          0     Normal
# 4   54    1           NAP        150          195          0     Normal
#
#    MaxHR  ExerciseA0gi0a  Oldpeak ST_Slope  HeartDisease
# 0    172               0      0.0       Up             0
# 1    156               0      1.0     Flat             1
# 2     98               0      0.0       Up             0
# 3    108               1      1.5     Flat             1
# 4    122               0      0.0       Up             0

# %% [markdown]
# ## preprocessing

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    int64
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseA0gi0a  918 non-null    int64
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(8), object(3)
# memory usage: 86.2+ KB
# None

# %%
# Mapping dictionaries
chest_pain_mapping = {'ATA': 0, 'NAP': 1, 'ASY': 2, 'TA': 3}
resting_ecg_mapping = {'Normal': 0, 'ST': 1, 'LVH': 2}
st_slope_mapping = {'Up': 0, 'Flat': 1, 'Down': 2}

# Apply mappings
data['ChestPainType'] = data['ChestPainType'].map(chest_pain_mapping)
data['RestingECG'] = data['RestingECG'].map(resting_ecg_mapping)
data['ST_Slope'] = data['ST_Slope'].map(st_slope_mapping)

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    int64
#  2   ChestPainType   918 non-null    int64
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    int64
#  7   MaxHR           918 non-null    int64
#  8   ExerciseA0gi0a  918 non-null    int64
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    int64
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(11)
# memory usage: 86.2 KB
# None

# %%
data.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    1              0        140          289          0           0
# 1   49    0              1        160          180          0           0
# 2   37    1              0        130          283          0           1
# 3   48    0              2        138          214          0           0
# 4   54    1              1        150          195          0           0
#
#    MaxHR  ExerciseA0gi0a  Oldpeak  ST_Slope  HeartDisease
# 0    172               0      0.0         0             0
# 1    156               0      1.0         1             1
# 2     98               0      0.0         0             0
# 3    108               1      1.5         1             1
# 4    122               0      0.0         0             0

# %% [markdown]
# ## visualization

# %%
cardio_counts = data['HeartDisease'].value_counts()

plt.figure(figsize=(5, 3))
cardio_counts.plot(kind='bar', color=['skyblue', 'orange'], rot=0)
plt.title('Heart Column Value Counts')
plt.xlabel('Heart (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No Heart Disease', 'Heart Disease'], rotation=0)
plt.show()

# %%
corr_matrix = data.corr()

plt.figure(figsize=(12, 7)) 
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5, 
            cbar_kws={'shrink': 0.8})
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.title("Correlation Matrix of Numerical Columns in Crop Yield Data")
plt.tight_layout()
plt.show()

# %%
data = data.drop('RestingECG', axis=1)

# %%
plt.figure(figsize=(6, 3))
sns.histplot(data['Age'], bins=30, kde=True, color='blue')
plt.title('Age Distribution')
plt.xlabel('Age (Years)')
plt.ylabel('Frequency')
plt.show()

# %%
data.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  MaxHR  \
# 0   40    1              0        140          289          0    172
# 1   49    0              1        160          180          0    156
# 2   37    1              0        130          283          0     98
# 3   48    0              2        138          214          0    108
# 4   54    1              1        150          195          0    122
#
#    ExerciseA0gi0a  Oldpeak  ST_Slope  HeartDisease
# 0               0      0.0         0             0
# 1               0      1.0         1             1
# 2               0      0.0         0             0
# 3               1      1.5         1             1
# 4               0      0.0         0             0

# %%
plt.figure(figsize=(6, 3))
sns.countplot(x='Sex', hue='HeartDisease', data=data, palette='viridis')
plt.title('Heat Disease by Gender')
plt.xlabel('Sex (0 = Female, 1 = Male)')
plt.ylabel('Count')
plt.legend(title='HeartDisease', loc='upper right')
plt.show()

# %%
# Create Age Groups with 0 to 100 range
age_group_data = data.copy()
age_group_data['AgeGroup'] = pd.cut(data['Age'], bins=[0, 20, 40, 60, 80, 100], labels=['0-20', '21-40', '41-60', '61-80', '81-100'])
age_group_counts = age_group_data.groupby('AgeGroup')['HeartDisease'].value_counts().unstack().fillna(0)
age_group_counts.columns = ['No Disease', 'Heart Disease']

age_group_counts.plot(kind='bar', stacked=True, color=['#1f77b4', '#ff7f0e'], figsize=(6, 3))

plt.title('Heart Disease Frequency by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Number of People')
plt.xticks(rotation=45)
plt.legend(title='Condition')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 3))
sns.countplot(x='ExerciseA0gi0a', hue='HeartDisease', data=data, palette='Set1')
plt.title('HeartDisease by Active/Inactive Lifestyle')
plt.xlabel('Exercise (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.legend(title='HeartDisease', loc='upper right')
plt.show()

# %%
plt.figure(figsize=(6, 3))
sns.countplot(x='ST_Slope', hue='HeartDisease', data=data, palette='coolwarm')
plt.title('HeartDisease by ST_Slope Level')
plt.xlabel('ST_Slope Level (1 = Up, 2 = Flat, 3 = Down)')
plt.ylabel('Count')
plt.legend(title='HeartDisease', loc='upper right')
plt.show()

# %% [markdown]
# ## data split

# %%
X = data.drop(['HeartDisease'], axis=1)
y = data['HeartDisease']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## machine learning

# %% [markdown]
# ## random forest

# %%
rf = RandomForestClassifier(n_estimators=200, random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score

# Predict using the classifier
y_pred = rf.predict(X_test)

# Calculate Accuracy
accuracy = accuracy_score(y_test, y_pred)

# Calculate Precision, Recall, and F1 Score
precision = precision_score(y_test, y_pred, average='binary') 
recall = recall_score(y_test, y_pred, average='binary')
f1 = f1_score(y_test, y_pred, average='binary')

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# Print Results
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print(f"Confusion Matrix:\n{cm}")
# Out:
# Accuracy: 0.8804347826086957
# Precision: 0.9047619047619048
# Recall: 0.8878504672897196
# F1 Score: 0.8962264150943396
# Confusion Matrix:
# [[67 10]
#  [12 95]]

# %% [markdown]
# ## logistic

# %%
from sklearn.linear_model import LogisticRegression

# Initialize and train Logistic Regression
lr = LogisticRegression(random_state=42)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score

# Predict using the classifier
y_pred = lr.predict(X_test)

# Calculate Accuracy
accuracy = accuracy_score(y_test, y_pred)

# Calculate Precision, Recall, and F1 Score
precision = precision_score(y_test, y_pred, average='binary') 
recall = recall_score(y_test, y_pred, average='binary')
f1 = f1_score(y_test, y_pred, average='binary')

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# Print Results
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print(f"Confusion Matrix:\n{cm}")
# Out:
# Accuracy: 0.8369565217391305
# Precision: 0.8811881188118812
# Recall: 0.8317757009345794
# F1 Score: 0.8557692307692307
# Confusion Matrix:
# [[65 12]
#  [18 89]]

# %% [markdown]
# ## xgb

# %%
from xgboost import XGBClassifier

# Initialize and train XGBoost
xgb = XGBClassifier(n_estimators=200, random_state=42)
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score

# Predict using the classifier
y_pred = xgb.predict(X_test)

# Calculate Accuracy
accuracy = accuracy_score(y_test, y_pred)

# Calculate Precision, Recall, and F1 Score
precision = precision_score(y_test, y_pred, average='binary') 
recall = recall_score(y_test, y_pred, average='binary')
f1 = f1_score(y_test, y_pred, average='binary')

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# Print Results
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print(f"Confusion Matrix:\n{cm}")
# Out:
# Accuracy: 0.8641304347826086
# Precision: 0.91
# Recall: 0.8504672897196262
# F1 Score: 0.8792270531400966
# Confusion Matrix:
# [[68  9]
#  [16 91]]

# %% [markdown]
# ## deep learning

# %% [markdown]
# ## CNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Flatten, MaxPooling1D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
import numpy as np

# Reshape data for Conv1D: (samples, features, 1)
X_train_reshaped = np.expand_dims(X_train, axis=-1)
X_test_reshaped = np.expand_dims(X_test, axis=-1)

# Define the CNN model
model = Sequential()

# First Convolutional Layer
model.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(X_train.shape[1], 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.2))

# Second Convolutional Layer
model.add(Conv1D(filters=128, kernel_size=2, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.3))

# Flatten and Fully Connected Layer
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))

# Output Layer
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Learning rate reduction callback
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=0.0001, verbose=1)

# Train the model
history = model.fit(X_train_reshaped, y_train, epochs=200, batch_size=16, validation_data=(X_test_reshaped, y_test), callbacks=[reduce_lr])
# Out:
# Epoch 1/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.5948 - loss: 0.6597 - val_accuracy: 0.7826 - val_loss: 0.5235 - learning_rate: 0.0010
# Epoch 2/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7658 - loss: 0.5136 - val_accuracy: 0.8043 - val_loss: 0.4635 - learning_rate: 0.0010
# Epoch 3/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7392 - loss: 0.5440 - val_accuracy: 0.7826 - val_loss: 0.4707 - learning_rate: 0.0010
# Epoch 4/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7881 - loss: 0.4855 - val_accuracy: 0.7826 - val_loss: 0.4814 - learning_rate: 0.0010
# Epoch 5/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7735 - loss: 0.4659 - val_accuracy: 0.7989 - val_loss: 0.4482 - learning_rate: 0.0010
# Epoch 6/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7948 - loss: 0.4576 - val_accuracy: 0.7935 - val_loss: 0.4518 - learning_rate: 0.0010
# Epoch 7/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7723 - loss: 0.4988 - val_accuracy: 0.7989 - val_loss: 0.4572 - learning_rate: 0.0010
# Epoch 8/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7694 - loss: 0.4902 - val_accuracy: 0.8152 - val_loss: 0.4467 - learning_rate: 0.0010
# Epoch 9/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8015 - loss: 0.4680 - val_accuracy: 0.7935 - val_loss: 0.4608 - learning_rate: 0.0010
# Epoch 10/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7415 - loss: 0.5203 - val_accuracy: 0.8152 - val_loss: 0.4456 - learning_rate: 0.0010
# Epoch 11/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7829 - loss: 0.4753 - val_accuracy: 0.8152 - val_loss: 0.4525 - learning_rate: 0.0010
# Epoch 12/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7630 - loss: 0.4934 - val_accuracy: 0.7772 - val_loss: 0.4407 - learning_rate: 0.0010
# Epoch 13/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7979 - loss: 0.4471 - val_accuracy: 0.7826 - val_loss: 0.4682 - learning_rate: 0.0010
# Epoch 14/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7813 - loss: 0.4768 - val_accuracy: 0.7935 - val_loss: 0.4602 - learning_rate: 0.0010
# Epoch 15/200
# 39/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7826 - loss: 0.4455
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7827 - loss: 0.4476 - val_accuracy: 0.7880 - val_loss: 0.4523 - learning_rate: 0.0010
# Epoch 16/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7608 - loss: 0.4948 - val_accuracy: 0.7935 - val_loss: 0.4507 - learning_rate: 5.0000e-04
# Epoch 17/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7935 - loss: 0.4404 - val_accuracy: 0.7826 - val_loss: 0.4571 - learning_rate: 5.0000e-04
# Epoch 18/200
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7878 - loss: 0.4402
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7872 - loss: 0.4409 - val_accuracy: 0.8043 - val_loss: 0.4484 - learning_rate: 5.0000e-04
# Epoch 19/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8131 - loss: 0.4412 - val_accuracy: 0.8043 - val_loss: 0.4474 - learning_rate: 2.5000e-04
# Epoch 20/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7921 - loss: 0.4472 - val_accuracy: 0.7989 - val_loss: 0.4479 - learning_rate: 2.5000e-04
# Epoch 21/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7895 - loss: 0.4569
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7895 - loss: 0.4567 - val_accuracy: 0.8098 - val_loss: 0.4488 - learning_rate: 2.5000e-04
# Epoch 22/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8121 - loss: 0.4379 - val_accuracy: 0.8098 - val_loss: 0.4472 - learning_rate: 1.2500e-04
# Epoch 23/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7900 - loss: 0.4360 - val_accuracy: 0.8098 - val_loss: 0.4473 - learning_rate: 1.2500e-04
# Epoch 24/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7575 - loss: 0.4523
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0001.
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7580 - loss: 0.4521 - val_accuracy: 0.8098 - val_loss: 0.4470 - learning_rate: 1.2500e-04
# Epoch 25/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7914 - loss: 0.4324 - val_accuracy: 0.8098 - val_loss: 0.4485 - learning_rate: 1.0000e-04
# Epoch 26/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7841 - loss: 0.4269 - val_accuracy: 0.8098 - val_loss: 0.4469 - learning_rate: 1.0000e-04
# Epoch 27/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7939 - loss: 0.4664 - val_accuracy: 0.8098 - val_loss: 0.4481 - learning_rate: 1.0000e-04
# Epoch 28/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7859 - loss: 0.4617 - val_accuracy: 0.8152 - val_loss: 0.4474 - learning_rate: 1.0000e-04
# Epoch 29/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8030 - loss: 0.4570 - val_accuracy: 0.8098 - val_loss: 0.4467 - learning_rate: 1.0000e-04
# Epoch 30/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7860 - loss: 0.4721 - val_accuracy: 0.8098 - val_loss: 0.4461 - learning_rate: 1.0000e-04
# Epoch 31/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7935 - loss: 0.4577 - val_accuracy: 0.8098 - val_loss: 0.4470 - learning_rate: 1.0000e-04
# Epoch 32/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7902 - loss: 0.4400 - val_accuracy: 0.8098 - val_loss: 0.4464 - learning_rate: 1.0000e-04
# Epoch 33/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7750 - loss: 0.4564 - val_accuracy: 0.8098 - val_loss: 0.4476 - learning_rate: 1.0000e-04
# Epoch 34/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7867 - loss: 0.4432 - val_accuracy: 0.8098 - val_loss: 0.4485 - learning_rate: 1.0000e-04
# Epoch 35/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7941 - loss: 0.4514 - val_accuracy: 0.8098 - val_loss: 0.4466 - learning_rate: 1.0000e-04
# Epoch 36/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7918 - loss: 0.4591 - val_accuracy: 0.8152 - val_loss: 0.4474 - learning_rate: 1.0000e-04
# Epoch 37/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8115 - loss: 0.4187 - val_accuracy: 0.8152 - val_loss: 0.4466 - learning_rate: 1.0000e-04
# Epoch 38/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8113 - loss: 0.4270 - val_accuracy: 0.8207 - val_loss: 0.4461 - learning_rate: 1.0000e-04
# Epoch 39/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7925 - loss: 0.4234 - val_accuracy: 0.8152 - val_loss: 0.4453 - learning_rate: 1.0000e-04
# Epoch 40/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7784 - loss: 0.4726 - val_accuracy: 0.8152 - val_loss: 0.4463 - learning_rate: 1.0000e-04
# Epoch 41/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7991 - loss: 0.4192 - val_accuracy: 0.8043 - val_loss: 0.4461 - learning_rate: 1.0000e-04
# Epoch 42/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7743 - loss: 0.4630 - val_accuracy: 0.8152 - val_loss: 0.4480 - learning_rate: 1.0000e-04
# Epoch 43/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8057 - loss: 0.4597 - val_accuracy: 0.8098 - val_loss: 0.4493 - learning_rate: 1.0000e-04
# Epoch 44/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7749 - loss: 0.4426 - val_accuracy: 0.8098 - val_loss: 0.4459 - learning_rate: 1.0000e-04
# Epoch 45/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7848 - loss: 0.4220 - val_accuracy: 0.8152 - val_loss: 0.4466 - learning_rate: 1.0000e-04
# Epoch 46/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8008 - loss: 0.4254 - val_accuracy: 0.8098 - val_loss: 0.4462 - learning_rate: 1.0000e-04
# Epoch 47/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8056 - loss: 0.4206 - val_accuracy: 0.8098 - val_loss: 0.4479 - learning_rate: 1.0000e-04
# Epoch 48/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7779 - loss: 0.4638 - val_accuracy: 0.8098 - val_loss: 0.4479 - learning_rate: 1.0000e-04
# Epoch 49/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7592 - loss: 0.4822 - val_accuracy: 0.8043 - val_loss: 0.4479 - learning_rate: 1.0000e-04
# Epoch 50/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7597 - loss: 0.4631 - val_accuracy: 0.8098 - val_loss: 0.4490 - learning_rate: 1.0000e-04
# Epoch 51/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8191 - loss: 0.4338 - val_accuracy: 0.8098 - val_loss: 0.4494 - learning_rate: 1.0000e-04
# Epoch 52/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8039 - loss: 0.4444 - val_accuracy: 0.8043 - val_loss: 0.4488 - learning_rate: 1.0000e-04
# Epoch 53/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7771 - loss: 0.4602 - val_accuracy: 0.8098 - val_loss: 0.4507 - learning_rate: 1.0000e-04
# Epoch 54/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7886 - loss: 0.4290 - val_accuracy: 0.8098 - val_loss: 0.4497 - learning_rate: 1.0000e-04
# Epoch 55/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7927 - loss: 0.4466 - val_accuracy: 0.8098 - val_loss: 0.4496 - learning_rate: 1.0000e-04
# Epoch 56/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8055 - loss: 0.4283 - val_accuracy: 0.7989 - val_loss: 0.4478 - learning_rate: 1.0000e-04
# Epoch 57/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7813 - loss: 0.4532 - val_accuracy: 0.8098 - val_loss: 0.4498 - learning_rate: 1.0000e-04
# Epoch 58/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7678 - loss: 0.4463 - val_accuracy: 0.7989 - val_loss: 0.4493 - learning_rate: 1.0000e-04
# Epoch 59/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8097 - loss: 0.4469 - val_accuracy: 0.8098 - val_loss: 0.4503 - learning_rate: 1.0000e-04
# Epoch 60/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7662 - loss: 0.4564 - val_accuracy: 0.8043 - val_loss: 0.4489 - learning_rate: 1.0000e-04
# Epoch 61/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8052 - loss: 0.4302 - val_accuracy: 0.8043 - val_loss: 0.4491 - learning_rate: 1.0000e-04
# Epoch 62/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8000 - loss: 0.4235 - val_accuracy: 0.8043 - val_loss: 0.4489 - learning_rate: 1.0000e-04
# Epoch 63/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7902 - loss: 0.4293 - val_accuracy: 0.8098 - val_loss: 0.4492 - learning_rate: 1.0000e-04
# Epoch 64/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7967 - loss: 0.4187 - val_accuracy: 0.8098 - val_loss: 0.4483 - learning_rate: 1.0000e-04
# Epoch 65/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7786 - loss: 0.4487 - val_accuracy: 0.8098 - val_loss: 0.4486 - learning_rate: 1.0000e-04
# Epoch 66/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7936 - loss: 0.4314 - val_accuracy: 0.8043 - val_loss: 0.4479 - learning_rate: 1.0000e-04
# Epoch 67/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7942 - loss: 0.4420 - val_accuracy: 0.7989 - val_loss: 0.4480 - learning_rate: 1.0000e-04
# Epoch 68/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7962 - loss: 0.4316 - val_accuracy: 0.8043 - val_loss: 0.4483 - learning_rate: 1.0000e-04
# Epoch 69/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8191 - loss: 0.4124 - val_accuracy: 0.8043 - val_loss: 0.4480 - learning_rate: 1.0000e-04
# Epoch 70/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7992 - loss: 0.4437 - val_accuracy: 0.8043 - val_loss: 0.4491 - learning_rate: 1.0000e-04
# Epoch 71/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7723 - loss: 0.4701 - val_accuracy: 0.8098 - val_loss: 0.4496 - learning_rate: 1.0000e-04
# Epoch 72/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8073 - loss: 0.4064 - val_accuracy: 0.8098 - val_loss: 0.4457 - learning_rate: 1.0000e-04
# Epoch 73/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8099 - loss: 0.4352 - val_accuracy: 0.8043 - val_loss: 0.4473 - learning_rate: 1.0000e-04
# Epoch 74/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8245 - loss: 0.3986 - val_accuracy: 0.8043 - val_loss: 0.4480 - learning_rate: 1.0000e-04
# Epoch 75/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7691 - loss: 0.4517 - val_accuracy: 0.8098 - val_loss: 0.4494 - learning_rate: 1.0000e-04
# Epoch 76/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7778 - loss: 0.4755 - val_accuracy: 0.8152 - val_loss: 0.4480 - learning_rate: 1.0000e-04
# Epoch 77/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7923 - loss: 0.4496 - val_accuracy: 0.8043 - val_loss: 0.4488 - learning_rate: 1.0000e-04
# Epoch 78/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8107 - loss: 0.4184 - val_accuracy: 0.8043 - val_loss: 0.4483 - learning_rate: 1.0000e-04
# Epoch 79/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7741 - loss: 0.4698 - val_accuracy: 0.8043 - val_loss: 0.4480 - learning_rate: 1.0000e-04
# Epoch 80/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7829 - loss: 0.4568 - val_accuracy: 0.8043 - val_loss: 0.4477 - learning_rate: 1.0000e-04
# Epoch 81/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8016 - loss: 0.4075 - val_accuracy: 0.7989 - val_loss: 0.4503 - learning_rate: 1.0000e-04
# Epoch 82/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8218 - loss: 0.4200 - val_accuracy: 0.8098 - val_loss: 0.4477 - learning_rate: 1.0000e-04
# Epoch 83/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7828 - loss: 0.4567 - val_accuracy: 0.8043 - val_loss: 0.4502 - learning_rate: 1.0000e-04
# Epoch 84/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7918 - loss: 0.4400 - val_accuracy: 0.8098 - val_loss: 0.4479 - learning_rate: 1.0000e-04
# Epoch 85/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7937 - loss: 0.4436 - val_accuracy: 0.8098 - val_loss: 0.4479 - learning_rate: 1.0000e-04
# Epoch 86/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7678 - loss: 0.4705 - val_accuracy: 0.7989 - val_loss: 0.4506 - learning_rate: 1.0000e-04
# Epoch 87/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7923 - loss: 0.4275 - val_accuracy: 0.8043 - val_loss: 0.4491 - learning_rate: 1.0000e-04
# Epoch 88/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7857 - loss: 0.4444 - val_accuracy: 0.8043 - val_loss: 0.4482 - learning_rate: 1.0000e-04
# Epoch 89/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8105 - loss: 0.4133 - val_accuracy: 0.8152 - val_loss: 0.4473 - learning_rate: 1.0000e-04
# Epoch 90/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8056 - loss: 0.4190 - val_accuracy: 0.8043 - val_loss: 0.4488 - learning_rate: 1.0000e-04
# Epoch 91/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8112 - loss: 0.4258 - val_accuracy: 0.8152 - val_loss: 0.4463 - learning_rate: 1.0000e-04
# Epoch 92/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7702 - loss: 0.4488 - val_accuracy: 0.8152 - val_loss: 0.4470 - learning_rate: 1.0000e-04
# Epoch 93/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7891 - loss: 0.4487 - val_accuracy: 0.8152 - val_loss: 0.4476 - learning_rate: 1.0000e-04
# Epoch 94/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8077 - loss: 0.4196 - val_accuracy: 0.7989 - val_loss: 0.4497 - learning_rate: 1.0000e-04
# Epoch 95/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7923 - loss: 0.4342 - val_accuracy: 0.8098 - val_loss: 0.4478 - learning_rate: 1.0000e-04
# Epoch 96/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7735 - loss: 0.4434 - val_accuracy: 0.8098 - val_loss: 0.4483 - learning_rate: 1.0000e-04
# Epoch 97/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7945 - loss: 0.4263 - val_accuracy: 0.8098 - val_loss: 0.4486 - learning_rate: 1.0000e-04
# Epoch 98/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7670 - loss: 0.4474 - val_accuracy: 0.8043 - val_loss: 0.4502 - learning_rate: 1.0000e-04
# Epoch 99/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7682 - loss: 0.4596 - val_accuracy: 0.8098 - val_loss: 0.4486 - learning_rate: 1.0000e-04
# Epoch 100/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8026 - loss: 0.4222 - val_accuracy: 0.8098 - val_loss: 0.4491 - learning_rate: 1.0000e-04
# Epoch 101/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8039 - loss: 0.4221 - val_accuracy: 0.8098 - val_loss: 0.4489 - learning_rate: 1.0000e-04
# Epoch 102/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8022 - loss: 0.3943 - val_accuracy: 0.7989 - val_loss: 0.4506 - learning_rate: 1.0000e-04
# Epoch 103/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8018 - loss: 0.4374 - val_accuracy: 0.8152 - val_loss: 0.4510 - learning_rate: 1.0000e-04
# Epoch 104/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8074 - loss: 0.4201 - val_accuracy: 0.8043 - val_loss: 0.4507 - learning_rate: 1.0000e-04
# Epoch 105/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7887 - loss: 0.4341 - val_accuracy: 0.8043 - val_loss: 0.4501 - learning_rate: 1.0000e-04
# Epoch 106/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7934 - loss: 0.4167 - val_accuracy: 0.8098 - val_loss: 0.4510 - learning_rate: 1.0000e-04
# Epoch 107/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7745 - loss: 0.4496 - val_accuracy: 0.8098 - val_loss: 0.4492 - learning_rate: 1.0000e-04
# Epoch 108/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7927 - loss: 0.4043 - val_accuracy: 0.8207 - val_loss: 0.4483 - learning_rate: 1.0000e-04
# Epoch 109/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8124 - loss: 0.4717 - val_accuracy: 0.8098 - val_loss: 0.4475 - learning_rate: 1.0000e-04
# Epoch 110/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8065 - loss: 0.4272 - val_accuracy: 0.8043 - val_loss: 0.4498 - learning_rate: 1.0000e-04
# Epoch 111/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7881 - loss: 0.4594 - val_accuracy: 0.8152 - val_loss: 0.4485 - learning_rate: 1.0000e-04
# Epoch 112/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7989 - loss: 0.4202 - val_accuracy: 0.8152 - val_loss: 0.4479 - learning_rate: 1.0000e-04
# Epoch 113/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8024 - loss: 0.4257 - val_accuracy: 0.8207 - val_loss: 0.4460 - learning_rate: 1.0000e-04
# Epoch 114/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8039 - loss: 0.4198 - val_accuracy: 0.8152 - val_loss: 0.4483 - learning_rate: 1.0000e-04
# Epoch 115/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8042 - loss: 0.4081 - val_accuracy: 0.8152 - val_loss: 0.4481 - learning_rate: 1.0000e-04
# Epoch 116/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8152 - loss: 0.4446 - val_accuracy: 0.8098 - val_loss: 0.4500 - learning_rate: 1.0000e-04
# Epoch 117/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7936 - loss: 0.4238 - val_accuracy: 0.8152 - val_loss: 0.4496 - learning_rate: 1.0000e-04
# Epoch 118/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7839 - loss: 0.4437 - val_accuracy: 0.8098 - val_loss: 0.4499 - learning_rate: 1.0000e-04
# Epoch 119/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8020 - loss: 0.4202 - val_accuracy: 0.7989 - val_loss: 0.4499 - learning_rate: 1.0000e-04
# Epoch 120/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7941 - loss: 0.4255 - val_accuracy: 0.8207 - val_loss: 0.4490 - learning_rate: 1.0000e-04
# Epoch 121/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7690 - loss: 0.4671 - val_accuracy: 0.8207 - val_loss: 0.4496 - learning_rate: 1.0000e-04
# Epoch 122/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7580 - loss: 0.4760 - val_accuracy: 0.8098 - val_loss: 0.4517 - learning_rate: 1.0000e-04
# Epoch 123/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7913 - loss: 0.4029 - val_accuracy: 0.8207 - val_loss: 0.4494 - learning_rate: 1.0000e-04
# Epoch 124/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8193 - loss: 0.4007 - val_accuracy: 0.8043 - val_loss: 0.4511 - learning_rate: 1.0000e-04
# Epoch 125/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7827 - loss: 0.4362 - val_accuracy: 0.8152 - val_loss: 0.4493 - learning_rate: 1.0000e-04
# Epoch 126/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8137 - loss: 0.4240 - val_accuracy: 0.8043 - val_loss: 0.4511 - learning_rate: 1.0000e-04
# Epoch 127/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7855 - loss: 0.4341 - val_accuracy: 0.8098 - val_loss: 0.4522 - learning_rate: 1.0000e-04
# Epoch 128/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7983 - loss: 0.4513 - val_accuracy: 0.8043 - val_loss: 0.4525 - learning_rate: 1.0000e-04
# Epoch 129/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7719 - loss: 0.4436 - val_accuracy: 0.8152 - val_loss: 0.4503 - learning_rate: 1.0000e-04
# Epoch 130/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7869 - loss: 0.4495 - val_accuracy: 0.8152 - val_loss: 0.4517 - learning_rate: 1.0000e-04
# Epoch 131/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7903 - loss: 0.4409 - val_accuracy: 0.8098 - val_loss: 0.4520 - learning_rate: 1.0000e-04
# Epoch 132/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8176 - loss: 0.4090 - val_accuracy: 0.8207 - val_loss: 0.4503 - learning_rate: 1.0000e-04
# Epoch 133/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8200 - loss: 0.4143 - val_accuracy: 0.8098 - val_loss: 0.4506 - learning_rate: 1.0000e-04
# Epoch 134/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8104 - loss: 0.4414 - val_accuracy: 0.8152 - val_loss: 0.4495 - learning_rate: 1.0000e-04
# Epoch 135/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7752 - loss: 0.4513 - val_accuracy: 0.8207 - val_loss: 0.4504 - learning_rate: 1.0000e-04
# Epoch 136/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8016 - loss: 0.4339 - val_accuracy: 0.8152 - val_loss: 0.4495 - learning_rate: 1.0000e-04
# Epoch 137/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7648 - loss: 0.4655 - val_accuracy: 0.8207 - val_loss: 0.4499 - learning_rate: 1.0000e-04
# Epoch 138/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8053 - loss: 0.4250 - val_accuracy: 0.8207 - val_loss: 0.4497 - learning_rate: 1.0000e-04
# Epoch 139/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8022 - loss: 0.4227 - val_accuracy: 0.8152 - val_loss: 0.4518 - learning_rate: 1.0000e-04
# Epoch 140/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7635 - loss: 0.4517 - val_accuracy: 0.8152 - val_loss: 0.4500 - learning_rate: 1.0000e-04
# Epoch 141/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7936 - loss: 0.4466 - val_accuracy: 0.8207 - val_loss: 0.4517 - learning_rate: 1.0000e-04
# Epoch 142/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8153 - loss: 0.4224 - val_accuracy: 0.8098 - val_loss: 0.4533 - learning_rate: 1.0000e-04
# Epoch 143/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7919 - loss: 0.4501 - val_accuracy: 0.8152 - val_loss: 0.4530 - learning_rate: 1.0000e-04
# Epoch 144/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7978 - loss: 0.4182 - val_accuracy: 0.8152 - val_loss: 0.4524 - learning_rate: 1.0000e-04
# Epoch 145/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7730 - loss: 0.4221 - val_accuracy: 0.8152 - val_loss: 0.4523 - learning_rate: 1.0000e-04
# Epoch 146/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7939 - loss: 0.4206 - val_accuracy: 0.8207 - val_loss: 0.4527 - learning_rate: 1.0000e-04
# Epoch 147/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7863 - loss: 0.4223 - val_accuracy: 0.8152 - val_loss: 0.4519 - learning_rate: 1.0000e-04
# Epoch 148/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7832 - loss: 0.4239 - val_accuracy: 0.8152 - val_loss: 0.4513 - learning_rate: 1.0000e-04
# Epoch 149/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7849 - loss: 0.4359 - val_accuracy: 0.8098 - val_loss: 0.4505 - learning_rate: 1.0000e-04
# Epoch 150/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8012 - loss: 0.4185 - val_accuracy: 0.8152 - val_loss: 0.4507 - learning_rate: 1.0000e-04
# Epoch 151/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8053 - loss: 0.4206 - val_accuracy: 0.8152 - val_loss: 0.4497 - learning_rate: 1.0000e-04
# Epoch 152/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8159 - loss: 0.3953 - val_accuracy: 0.8152 - val_loss: 0.4506 - learning_rate: 1.0000e-04
# Epoch 153/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7968 - loss: 0.4490 - val_accuracy: 0.8152 - val_loss: 0.4490 - learning_rate: 1.0000e-04
# Epoch 154/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8251 - loss: 0.3990 - val_accuracy: 0.8152 - val_loss: 0.4501 - learning_rate: 1.0000e-04
# Epoch 155/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8171 - loss: 0.4091 - val_accuracy: 0.8207 - val_loss: 0.4516 - learning_rate: 1.0000e-04
# Epoch 156/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8223 - loss: 0.3874 - val_accuracy: 0.8207 - val_loss: 0.4505 - learning_rate: 1.0000e-04
# Epoch 157/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7914 - loss: 0.4336 - val_accuracy: 0.8207 - val_loss: 0.4524 - learning_rate: 1.0000e-04
# Epoch 158/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8053 - loss: 0.3988 - val_accuracy: 0.8207 - val_loss: 0.4544 - learning_rate: 1.0000e-04
# Epoch 159/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8007 - loss: 0.4345 - val_accuracy: 0.8207 - val_loss: 0.4536 - learning_rate: 1.0000e-04
# Epoch 160/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8048 - loss: 0.3988 - val_accuracy: 0.8152 - val_loss: 0.4533 - learning_rate: 1.0000e-04
# Epoch 161/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7983 - loss: 0.4088 - val_accuracy: 0.8152 - val_loss: 0.4551 - learning_rate: 1.0000e-04
# Epoch 162/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8055 - loss: 0.4085 - val_accuracy: 0.8152 - val_loss: 0.4524 - learning_rate: 1.0000e-04
# Epoch 163/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7917 - loss: 0.4417 - val_accuracy: 0.8152 - val_loss: 0.4521 - learning_rate: 1.0000e-04
# Epoch 164/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8002 - loss: 0.4220 - val_accuracy: 0.8152 - val_loss: 0.4541 - learning_rate: 1.0000e-04
# Epoch 165/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7855 - loss: 0.4205 - val_accuracy: 0.8152 - val_loss: 0.4505 - learning_rate: 1.0000e-04
# Epoch 166/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8081 - loss: 0.4013 - val_accuracy: 0.8207 - val_loss: 0.4507 - learning_rate: 1.0000e-04
# Epoch 167/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7909 - loss: 0.4263 - val_accuracy: 0.8152 - val_loss: 0.4514 - learning_rate: 1.0000e-04
# Epoch 168/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7838 - loss: 0.4165 - val_accuracy: 0.8152 - val_loss: 0.4487 - learning_rate: 1.0000e-04
# Epoch 169/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7977 - loss: 0.4096 - val_accuracy: 0.8207 - val_loss: 0.4492 - learning_rate: 1.0000e-04
# Epoch 170/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8165 - loss: 0.4134 - val_accuracy: 0.8098 - val_loss: 0.4492 - learning_rate: 1.0000e-04
# Epoch 171/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7873 - loss: 0.4400 - val_accuracy: 0.8152 - val_loss: 0.4507 - learning_rate: 1.0000e-04
# Epoch 172/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8032 - loss: 0.4126 - val_accuracy: 0.8207 - val_loss: 0.4502 - learning_rate: 1.0000e-04
# Epoch 173/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7951 - loss: 0.4136 - val_accuracy: 0.8207 - val_loss: 0.4501 - learning_rate: 1.0000e-04
# Epoch 174/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8353 - loss: 0.3789 - val_accuracy: 0.8152 - val_loss: 0.4517 - learning_rate: 1.0000e-04
# Epoch 175/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7726 - loss: 0.4463 - val_accuracy: 0.8207 - val_loss: 0.4503 - learning_rate: 1.0000e-04
# Epoch 176/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8113 - loss: 0.4078 - val_accuracy: 0.8207 - val_loss: 0.4526 - learning_rate: 1.0000e-04
# Epoch 177/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7921 - loss: 0.4383 - val_accuracy: 0.8098 - val_loss: 0.4524 - learning_rate: 1.0000e-04
# Epoch 178/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7944 - loss: 0.4040 - val_accuracy: 0.8098 - val_loss: 0.4521 - learning_rate: 1.0000e-04
# Epoch 179/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8198 - loss: 0.3967 - val_accuracy: 0.8152 - val_loss: 0.4572 - learning_rate: 1.0000e-04
# Epoch 180/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7965 - loss: 0.4429 - val_accuracy: 0.8261 - val_loss: 0.4532 - learning_rate: 1.0000e-04
# Epoch 181/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8109 - loss: 0.4025 - val_accuracy: 0.8152 - val_loss: 0.4519 - learning_rate: 1.0000e-04
# Epoch 182/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8311 - loss: 0.3788 - val_accuracy: 0.8207 - val_loss: 0.4531 - learning_rate: 1.0000e-04
# Epoch 183/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8206 - loss: 0.3993 - val_accuracy: 0.8152 - val_loss: 0.4522 - learning_rate: 1.0000e-04
# Epoch 184/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7890 - loss: 0.4201 - val_accuracy: 0.8261 - val_loss: 0.4531 - learning_rate: 1.0000e-04
# Epoch 185/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8218 - loss: 0.4141 - val_accuracy: 0.8207 - val_loss: 0.4516 - learning_rate: 1.0000e-04
# Epoch 186/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7861 - loss: 0.4425 - val_accuracy: 0.8261 - val_loss: 0.4529 - learning_rate: 1.0000e-04
# Epoch 187/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8113 - loss: 0.4264 - val_accuracy: 0.8207 - val_loss: 0.4551 - learning_rate: 1.0000e-04
# Epoch 188/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8055 - loss: 0.4066 - val_accuracy: 0.8261 - val_loss: 0.4517 - learning_rate: 1.0000e-04
# Epoch 189/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8015 - loss: 0.4168 - val_accuracy: 0.8152 - val_loss: 0.4516 - learning_rate: 1.0000e-04
# Epoch 190/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8211 - loss: 0.4261 - val_accuracy: 0.8207 - val_loss: 0.4514 - learning_rate: 1.0000e-04
# Epoch 191/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8161 - loss: 0.4078 - val_accuracy: 0.8098 - val_loss: 0.4520 - learning_rate: 1.0000e-04
# Epoch 192/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7955 - loss: 0.4167 - val_accuracy: 0.8152 - val_loss: 0.4524 - learning_rate: 1.0000e-04
# Epoch 193/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8099 - loss: 0.4136 - val_accuracy: 0.8207 - val_loss: 0.4508 - learning_rate: 1.0000e-04
# Epoch 194/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8281 - loss: 0.4074 - val_accuracy: 0.8261 - val_loss: 0.4509 - learning_rate: 1.0000e-04
# Epoch 195/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8071 - loss: 0.4066 - val_accuracy: 0.8207 - val_loss: 0.4559 - learning_rate: 1.0000e-04
# Epoch 196/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7807 - loss: 0.4377 - val_accuracy: 0.8152 - val_loss: 0.4562 - learning_rate: 1.0000e-04
# Epoch 197/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7994 - loss: 0.4147 - val_accuracy: 0.8152 - val_loss: 0.4563 - learning_rate: 1.0000e-04
# Epoch 198/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8128 - loss: 0.3998 - val_accuracy: 0.8207 - val_loss: 0.4538 - learning_rate: 1.0000e-04
# Epoch 199/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8069 - loss: 0.4251 - val_accuracy: 0.8207 - val_loss: 0.4548 - learning_rate: 1.0000e-04
# Epoch 200/200
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8281 - loss: 0.4041 - val_accuracy: 0.8152 - val_loss: 0.4515 - learning_rate: 1.0000e-04

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Make predictions on the test set
y_pred = model.predict(X_test_reshaped)
y_pred = (y_pred > 0.5).astype(int)  # Convert probabilities to binary labels

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

# Print the metrics
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')
print(f'Confusion Matrix:\n{conf_matrix}')
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Accuracy: 0.8152173913043478
# Precision: 0.8067226890756303
# Recall: 0.897196261682243
# F1 Score: 0.8495575221238938
# Confusion Matrix:
# [[54 23]
#  [11 96]]
